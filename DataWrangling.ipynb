# %% [markdown]
# ### What is Data Wrangling?
# Data wrangling (also called data munging) is the process of cleaning, transforming, and preparing raw data into a format that is easier to analyze.
#
# When you get real-world data, it’s usually:
#
# Messy
#
# Incomplete
#
# Inconsistent
#
# Containing errors or duplicates
#
# So before you can run analysis or build models, you have to wrangle (fix/reshape) the data.

# %% [markdown]
# ### Steps in Data Wrangling (with examples)
#
# Data Cleaning
#
# Handle missing values → fill them (imputation) or drop them.
#
# Fix inconsistent categories → e.g., "Male", "male", "M" → make all "male".
#
# Remove typos and formatting issues.
#
# Data Transformation
#
# Change column types → e.g., "Age" from string → numeric.
#
# Scale or normalize numbers (if needed).
#
# Standardize formats (dates, currency, etc.).
#
# Data Enrichment / Feature Engineering
#
# Add new useful features → e.g., FamilySize = SibSp + Parch + 1.
#
# Extract information → e.g., title (Mr, Mrs) from Name.
#
# Data Reduction
#
# Remove irrelevant columns.
#
# Remove duplicate rows.
#
# Aggregate or group data (summarize).
#
# Handling Outliers
#
# Detect extreme/unrealistic values (e.g., negative age).
#
# Decide whether to cap, transform, or remove them.

# %% [markdown]
# **Example before cleaning data**
# Name: "  SMITH, Mr. John  "
# Sex: "Male "
# Age: NaN
# Fare: 0
# Embarked: "S "
#
# **After Data Cleaning**
# Name: "Smith, Mr. John"
# Sex: "male"
# Age: 32  (filled with median)
# Fare: 14.45 (fixed 0 → median)
# Embarked: "S"

# %% [markdown]
# ### Handling Missing Data
#
# Find out how many missing values are in each column.
#
# Drop rows where Age is missing.
#
# Fill missing Age values with the mean age.
#
# Fill missing Embarked values with the most frequent port.
#
# Replace missing Cabin values with "Unknown".
#
# **Removing Duplicates**
#
# Check if there are any duplicate rows. If yes, remove them.
#
# How many duplicate Name entries exist?
#
# **String Operations**
#
# Extract passenger titles (Mr, Mrs, Miss, etc.) from the Name column.
#
# Standardize Sex column values so they’re exactly "Male" or "Female" (capitalize them).
#
# Create a new column Deck by taking the first letter from Cabin (e.g., C85 → C).
#
# **Feature Engineering**
#
# Create a new column FamilySize = SibSp + Parch + 1.
#
# Create a new column IsAlone = 1 if FamilySize == 1 else 0.
#
# Bin ages into groups (Child <12, Teen 12–18, Adult 19–59, Senior >=60).
#
# Create a column FarePerPerson = Fare / FamilySize.
#
# **Filtering & Conditional Updates**
#
# Replace fares of 0 with the median fare.
#
# Replace age outliers (say <1 or >80) with NaN.
#
# Create a column HighFare = 1 if fare > 100, else 0.
#
# **Merging & Joining**
#
# Suppose you have a small dataset of Titanic passengers with their country of origin. Merge it with the main dataset on PassengerId.
#
# Split Name into FirstName and LastName.
#
# **Final Cleanup**
#
# Reorder columns logically: PassengerId, Name, Sex, Age, Pclass, Embarked, ... etc.

# %% [markdown]
# # Find out how many missing values are in each column.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Drop rows where Age is missing.

# %%
df.dropna(subset=['Age'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %% [markdown]
# # Fill missing Age values with the mean age.

# %%
df.Age.fillna(df.Age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# # Fill missing Embarked values with the most frequent port.

# %%
df.Embarked.value_counts().idxmax()
# Out:
# 'S'

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.Embarked.fillna(df.Embarked.value_counts().idxmax())
#  df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# # Replace missing Cabin values with "Unknown".

# %%
df.Cabin.fillna('Unknown')
# Out:
# 0      Unknown
# 1          C85
# 2      Unknown
# 3         C123
# 4      Unknown
#         ...
# 886    Unknown
# 887        B42
# 888    Unknown
# 889       C148
# 890    Unknown
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# # Check if there are any duplicate rows. If yes, remove them.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # How many duplicate Name entries exist?

# %%
df['Name'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Extract passenger titles (Mr, Mrs, Miss, etc.) from the Name column.

# %%
#df['title']=df.Name.str.extract(r',\s*([^\.]+)\.')

df['Title'] = df['Name'].str.extract(r',\s*([^\.]+\.)')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.
# 4        0            373450   8.0500   NaN        S    Mr    Mr.
# ..     ...               ...      ...   ...      ...   ...    ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.
# 887      0            112053  30.0000   B42        S  Miss  Miss.
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.
# 889      0            111369  30.0000  C148        C    Mr    Mr.
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.
#
# [891 rows x 14 columns]

# %% [markdown]
# # Standardize Sex column values so they’re exactly "Male" or "Female" (capitalize them).

# %%
df['Sex']= df.Sex.str.strip().str.capitalize()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.
# 4        0            373450   8.0500   NaN        S    Mr    Mr.
# ..     ...               ...      ...   ...      ...   ...    ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.
# 887      0            112053  30.0000   B42        S  Miss  Miss.
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.
# 889      0            111369  30.0000  C148        C    Mr    Mr.
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.
#
# [891 rows x 14 columns]

# %% [markdown]
# # Create a new column Deck by taking the first letter from Cabin (e.g., C85 → C).

# %%
df['Deck']= df.Cabin.str.extract(r"^(.)")
# df['Deck']=df.Cabin.str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
# [891 rows x 15 columns]

# %% [markdown]
# # Create a new column FamilySize = SibSp + Parch + 1.

# %%
df['FamilySize']=df.SibSp+ df.Parch+1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
#      FamilySize
# 0             2
# 1             2
# 2             1
# 3             2
# 4             1
# ..          ...
# 886           1
# 887           1
# 888           4
# 889           1
# 890           1
#
# [891 rows x 16 columns]

# %% [markdown]
# # Create a new column IsAlone = 1 if FamilySize == 1 else 0.

# %%
df['IsAlone'] = df['FamilySize'].apply(lambda x: 1 if x == 1 else 0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
#      FamilySize  IsAlone
# 0             2        0
# 1             2        0
# 2             1        1
# 3             2        0
# 4             1        1
# ..          ...      ...
# 886           1        1
# 887           1        1
# 888           4        0
# 889           1        1
# 890           1        1
#
# [891 rows x 17 columns]

# %% [markdown]
# # Bin ages into groups (Child <12, Teen 12–18, Adult 19–59, Senior >=60).

# %%
bins=[0,12,19,60,100]
labels=['Child','Teen','Adult','Senior']
df['AgeGroup']= pd.cut(df.Age, bins=bins, labels=labels, right=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
#      FamilySize  IsAlone AgeGroup
# 0             2        0    Adult
# 1             2        0    Adult
# 2             1        1    Adult
# 3             2        0    Adult
# 4             1        1    Adult
# ..          ...      ...      ...
# 886           1        1    Adult
# 887           1        1    Adult
# 888           4        0      NaN
# 889           1        1    Adult
# 890           1        1    Adult
#
# [891 rows x 18 columns]

# %% [markdown]
# # Create a column FarePerPerson = Fare / FamilySize.

# %%
df['FarePerPerson']=df['Fare']/df['FamilySize']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
#      FamilySize  IsAlone AgeGroup  FarePerPerson
# 0             2        0    Adult        3.62500
# 1             2        0    Adult       35.64165
# 2             1        1    Adult        7.92500
# 3             2        0    Adult       26.55000
# 4             1        1    Adult        8.05000
# ..          ...      ...      ...            ...
# 886           1        1    Adult       13.00000
# 887           1        1    Adult       30.00000
# 888           4        0      NaN        5.86250
# 889           1        1    Adult       30.00000
# 890           1        1    Adult        7.75000
#
# [891 rows x 19 columns]

# %% [markdown]
# # Replace fares of 0 with the median fare.

# %%
median= df.Fare.median()

# %%
df.loc[df.Fare==0, "Fare"]= median

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
#      FamilySize  IsAlone AgeGroup  FarePerPerson
# 0             2        0    Adult        3.62500
# 1             2        0    Adult       35.64165
# 2             1        1    Adult        7.92500
# 3             2        0    Adult       26.55000
# 4             1        1    Adult        8.05000
# ..          ...      ...      ...            ...
# 886           1        1    Adult       13.00000
# 887           1        1    Adult       30.00000
# 888           4        0      NaN        5.86250
# 889           1        1    Adult       30.00000
# 890           1        1    Adult        7.75000
#
# [891 rows x 19 columns]

# %% [markdown]
# # Replace age outliers (say <1 or >80) with NaN.

# %%
df.loc[(df.Age<1) | (df.Age>80), "Age"]= np.nan

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
#      FamilySize  IsAlone AgeGroup  FarePerPerson
# 0             2        0    Adult        3.62500
# 1             2        0    Adult       35.64165
# 2             1        1    Adult        7.92500
# 3             2        0    Adult       26.55000
# 4             1        1    Adult        8.05000
# ..          ...      ...      ...            ...
# 886           1        1    Adult       13.00000
# 887           1        1    Adult       30.00000
# 888           4        0      NaN        5.86250
# 889           1        1    Adult       30.00000
# 890           1        1    Adult        7.75000
#
# [891 rows x 19 columns]

# %% [markdown]
# # Create a column HighFare = 1 if fare > 100, else 0.

# %%
df['HighFare']=df.Fare.apply(lambda x: 1 if x>100 else 0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked title  Title Deck  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr    Mr.  NaN
# 1        0          PC 17599  71.2833   C85        C   Mrs   Mrs.    C
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  Miss.  NaN
# 3        0            113803  53.1000  C123        S   Mrs   Mrs.    C
# 4        0            373450   8.0500   NaN        S    Mr    Mr.  NaN
# ..     ...               ...      ...   ...      ...   ...    ...  ...
# 886      0            211536  13.0000   NaN        S   Rev   Rev.  NaN
# 887      0            112053  30.0000   B42        S  Miss  Miss.    B
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  Miss.  NaN
# 889      0            111369  30.0000  C148        C    Mr    Mr.    C
# 890      0            370376   7.7500   NaN        Q    Mr    Mr.  NaN
#
#      FamilySize  IsAlone AgeGroup  FarePerPerson  HighFare
# 0             2        0    Adult        3.62500         0
# 1             2        0    Adult       35.64165         0
# 2             1        1    Adult        7.92500         0
# 3             2        0    Adult       26.55000         0
# 4             1        1    Adult        8.05000         0
# ..          ...      ...      ...            ...       ...
# 886           1        1    Adult       13.00000         0
# 887           1        1    Adult       30.00000         0
# 888           4        0      NaN        5.86250         0
# 889           1        1    Adult       30.00000         0
# 890           1        1    Adult        7.75000         0
#
# [891 rows x 20 columns]

# %% [markdown]
# # Split Name into FirstName and LastName.

# %%
df[['LastName', 'FirstName']] = df['Name'].str.split(',', n=1, expand=True)
df['FirstName'] = df['FirstName'].str.strip()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare  ... title  Title Deck FamilySize  \
# 0        0         A/5 21171   7.2500  ...    Mr    Mr.  NaN          2
# 1        0          PC 17599  71.2833  ...   Mrs   Mrs.    C          2
# 2        0  STON/O2. 3101282   7.9250  ...  Miss  Miss.  NaN          1
# 3        0            113803  53.1000  ...   Mrs   Mrs.    C          2
# 4        0            373450   8.0500  ...    Mr    Mr.  NaN          1
# ..     ...               ...      ...  ...   ...    ...  ...        ...
# 886      0            211536  13.0000  ...   Rev   Rev.  NaN          1
# 887      0            112053  30.0000  ...  Miss  Miss.    B          1
# 888      2        W./C. 6607  23.4500  ...  Miss  Miss.  NaN          4
# 889      0            111369  30.0000  ...    Mr    Mr.    C          1
# 890      0            370376   7.7500  ...    Mr    Mr.  NaN          1
#
#     IsAlone  AgeGroup  FarePerPerson HighFare   LastName  \
# 0         0     Adult        3.62500        0     Braund
# 1         0     Adult       35.64165        0    Cumings
# 2         1     Adult        7.92500        0  Heikkinen
# 3         0     Adult       26.55000        0   Futrelle
# 4         1     Adult        8.05000        0      Allen
# ..      ...       ...            ...      ...        ...
# 886       1     Adult       13.00000        0   Montvila
# 887       1     Adult       30.00000        0     Graham
# 888       0       NaN        5.86250        0   Johnston
# 889       1     Adult       30.00000        0       Behr
# 890       1     Adult        7.75000        0     Dooley
#
#                                       FirstName
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# 3            Mrs. Jacques Heath (Lily May Peel)
# 4                             Mr. William Henry
# ..                                          ...
# 886                                 Rev. Juozas
# 887                        Miss. Margaret Edith
# 888              Miss. Catherine Helen "Carrie"
# 889                             Mr. Karl Howell
# 890                                 Mr. Patrick
#
# [891 rows x 22 columns]

# %% [markdown]
# # Suppose you have a small dataset of Titanic passengers with their country of origin. Merge it with the main dataset on PassengerId.

# %%
country_data = pd.DataFrame({
    "PassengerId": [1, 2, 3, 4],
    "Country": ["UK", "USA", "France", "Germany"]
})

# %%
merged_df = df.merge(country_data, on="PassengerId", how="left")

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    Male  27.0      0
# 887                       Graham, Miss. Margaret Edith  Female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  Female   NaN      1
# 889                              Behr, Mr. Karl Howell    Male  26.0      0
# 890                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare  ...  Title Deck FamilySize IsAlone  \
# 0        0         A/5 21171   7.2500  ...    Mr.  NaN          2       0
# 1        0          PC 17599  71.2833  ...   Mrs.    C          2       0
# 2        0  STON/O2. 3101282   7.9250  ...  Miss.  NaN          1       1
# 3        0            113803  53.1000  ...   Mrs.    C          2       0
# 4        0            373450   8.0500  ...    Mr.  NaN          1       1
# ..     ...               ...      ...  ...    ...  ...        ...     ...
# 886      0            211536  13.0000  ...   Rev.  NaN          1       1
# 887      0            112053  30.0000  ...  Miss.    B          1       1
# 888      2        W./C. 6607  23.4500  ...  Miss.  NaN          4       0
# 889      0            111369  30.0000  ...    Mr.    C          1       1
# 890      0            370376   7.7500  ...    Mr.  NaN          1       1
#
#     AgeGroup  FarePerPerson  HighFare   LastName  \
# 0      Adult        3.62500         0     Braund
# 1      Adult       35.64165         0    Cumings
# 2      Adult        7.92500         0  Heikkinen
# 3      Adult       26.55000         0   Futrelle
# 4      Adult        8.05000         0      Allen
# ..       ...            ...       ...        ...
# 886    Adult       13.00000         0   Montvila
# 887    Adult       30.00000         0     Graham
# 888      NaN        5.86250         0   Johnston
# 889    Adult       30.00000         0       Behr
# 890    Adult        7.75000         0     Dooley
#
#                                       FirstName  Country
# 0                               Mr. Owen Harris       UK
# 1    Mrs. John Bradley (Florence Briggs Thayer)      USA
# 2                                   Miss. Laina   France
# 3            Mrs. Jacques Heath (Lily May Peel)  Germany
# 4                             Mr. William Henry      NaN
# ..                                          ...      ...
# 886                                 Rev. Juozas      NaN
# 887                        Miss. Margaret Edith      NaN
# 888              Miss. Catherine Helen "Carrie"      NaN
# 889                             Mr. Karl Howell      NaN
# 890                                 Mr. Patrick      NaN
#
# [891 rows x 23 columns]

# %%
merged_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    Male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0      1
# 2                             Heikkinen, Miss. Laina  Female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0      1
# 4                           Allen, Mr. William Henry    Male  35.0      0
# 5                                   Moran, Mr. James    Male   NaN      0
# 6                            McCarthy, Mr. Timothy J    Male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    Male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  Female  14.0      1
#
#    Parch            Ticket     Fare  ...    Title Deck FamilySize IsAlone  \
# 0      0         A/5 21171   7.2500  ...      Mr.  NaN          2       0
# 1      0          PC 17599  71.2833  ...     Mrs.    C          2       0
# 2      0  STON/O2. 3101282   7.9250  ...    Miss.  NaN          1       1
# 3      0            113803  53.1000  ...     Mrs.    C          2       0
# 4      0            373450   8.0500  ...      Mr.  NaN          1       1
# 5      0            330877   8.4583  ...      Mr.  NaN          1       1
# 6      0             17463  51.8625  ...      Mr.    E          1       1
# 7      1            349909  21.0750  ...  Master.  NaN          5       0
# 8      2            347742  11.1333  ...     Mrs.  NaN          3       0
# 9      0            237736  30.0708  ...     Mrs.  NaN          2       0
#
#   AgeGroup  FarePerPerson  HighFare   LastName  \
# 0    Adult        3.62500         0     Braund
# 1    Adult       35.64165         0    Cumings
# 2    Adult        7.92500         0  Heikkinen
# 3    Adult       26.55000         0   Futrelle
# 4    Adult        8.05000         0      Allen
# 5      NaN        8.45830         0      Moran
# 6    Adult       51.86250         0   McCarthy
# 7    Child        4.21500         0    Palsson
# 8    Adult        3.71110         0    Johnson
# 9     Teen       15.03540         0     Nasser
#
#                                     FirstName  Country
# 0                             Mr. Owen Harris       UK
# 1  Mrs. John Bradley (Florence Briggs Thayer)      USA
# 2                                 Miss. Laina   France
# 3          Mrs. Jacques Heath (Lily May Peel)  Germany
# 4                           Mr. William Henry      NaN
# 5                                   Mr. James      NaN
# 6                               Mr. Timothy J      NaN
# 7                       Master. Gosta Leonard      NaN
# 8    Mrs. Oscar W (Elisabeth Vilhelmina Berg)      NaN
# 9                 Mrs. Nicholas (Adele Achem)      NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# # Reorder columns logically: PassengerId, Name, Sex, Age, Pclass, Embarked, ... etc.

# %%
print(df.columns.tolist())
new_order = ['PassengerId', 'Name', 'Sex', 'Age', 'Pclass', 'Embarked', 'Fare', 'Survived']
df = df[new_order]
print(df.head())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'title', 'Title', 'Deck', 'FamilySize', 'IsAlone', 'AgeGroup', 'FarePerPerson', 'HighFare', 'LastName', 'FirstName']
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    Male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  Female
# 2            3                             Heikkinen, Miss. Laina  Female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female
# 4            5                           Allen, Mr. William Henry    Male
#
#     Age  Pclass Embarked     Fare  Survived
# 0  22.0       3        S   7.2500         0
# 1  38.0       1        C  71.2833         1
# 2  26.0       3        S   7.9250         1
# 3  35.0       1        S  53.1000         1
# 4  35.0       3        S   8.0500         0
